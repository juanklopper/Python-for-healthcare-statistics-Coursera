# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/googlecolab/colabtools/blob/master/notebooks/colab-github-demo.ipynb)

# %% [markdown]
# # Clinical research

# %% [markdown]
# <div><img src="https://drive.google.com/uc?id=1sQfuEM09OlKYGpNQ-nsXnpW8OogryOJv" width=250/></div><div><img src="https://drive.google.com/uc?id=16jSLpztk9lAMJ3X28K0rkPrdz2U0DvJ-" width=200/></div><div><img src="https://drive.google.com/uc?id=1b-pCh1IVchhcpyurIF4eQi-kAMCYNyDb" width=200/></div>

# %% [markdown]
# Load Colab to your Google Drive: https://colab.research.google.com/

# %% [markdown]
# This is a simple English sentence.

# %% [markdown]
# # Title

# %% [markdown]
# ## Subheading

# %%
# Code comment
print('This is a line of code.')
# Out:
# This is a line of code.

# %%
# Simple arithmetic
2 + 2
# Out:
# 4

# %%
4 - 2
# Out:
# 2

# %% [markdown]
# ### Exercises

# %% [markdown]
# 1. Create a title named Arithmetic
# 2. Create a subtitle named Multiplication
# 3. Write a line of code, following an appropriate comment, to multiply 3 and 4
# 4. Write a line of code, following an appropriate comment, to print: 'This is easy.' to the screen
# 5. Write the same sentence as in (4) but in a text cell.

# %% [markdown]
# ### Solution

# %% [markdown]
# See note book 01 Solution
